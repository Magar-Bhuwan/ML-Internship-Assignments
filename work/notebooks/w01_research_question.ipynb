# %% [markdown]
# <a href="https://colab.research.google.com/github/Magar-Bhuwan/ML-Internship-Assignments/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ### My lane:
# Product Performance. I chose this lane because businesses need to know which products contribute the most to revenue. Understanding product performance helps managers decide which products to promote, restock, or discontinue, making it a useful business question.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ### Decision
# Which products should receive more inventory and marketing investment?

# %% [markdown]
# ### Action
# Increase inventory and marketing for consistently high-performing products, and review low-performing products for improvement or discontinuation.

# %% [markdown]
# ### Cost of a Wrong Call
# Choosing the wrong products could lead to excess inventory, lost sales, and reduced profit because popular products may become unavailable while slow-moving products occupy storage space.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0cfd6419-3c94-4b2e-aca7-90a0eedc93aa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0cfd6419-3c94-4b2e-aca7-90a0eedc93aa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

data = pd.read_csv('Sales_Dataset_5000_Rows.csv')
data.head()
# Out:
#    Order_ID  Order_Date Customer_ID Customer_Name Product_ID Product_Name  \
# 0    100000  2023-10-09       C0502  Customer_458       P111     Backpack
# 1    100001  2024-03-08       C0066   Customer_62       P111     Backpack
# 2    100002  2023-07-23       C1117  Customer_860       P104         Desk
# 3    100003  2023-06-13       C0866  Customer_697       P110        Mouse
# 4    100004  2023-04-05       C0779  Customer_199       P104         Desk
#
#       Category Region  Quantity  Unit_Price  Discount_%  Revenue Payment_Mode
# 0  Accessories  South         2          45           0     90.0         Cash
# 1  Accessories  North         2          45          20     72.0         Card
# 2    Furniture  South         1         220          20    176.0          UPI
# 3  Electronics   East         5          25           0    125.0         Card
# 4    Furniture   East         6         220           0   1320.0       Online

# %%
data.shape
# Out:
# (5000, 13)

# %%
data['Product_Name'].nunique()
# Out:
# 12

# %%
print(data['Revenue'].sum())
# Out:
# 3753744.25

# %% [markdown]
# The above dataset contains 5000 sales records with 13 columns across 12 products name and total revenue is $3,753,744.25.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# 1. I can claim:
#
#       - The dataset shows which products generated the highest revenue.
#       - I can compare product performance within this dataset.
#
# 2. I cannot claim:
#
#       - These products will always be the best sellers.
#       - Revenue differences prove that one product is inherently better.
#       - The analysis proves why customers bought a product.
#
# 3. Remember:
#
#       - Correlation or observation is not causation.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - ✅ Every section above is filled — markdown thinking AND the code that backs it
# - ✅ The notebook runs top to bottom with no errors (Runtime → Run all)
# - ✅ No client names, URLs, or private queries anywhere
# - ✅ My claims use careful words: observed, measured, directional, decision-support
# - ✅ Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
